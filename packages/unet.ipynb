# %%
import torch
from torch import nn
import torch.nn.functional as F

# %%
class CNNEncoder(nn.Module):

    def __init__(self, nb_modalities=4 , nb_features=64):

        super(CNNEncoder, self).__init__()
        ...

    def forward(self, x):
        ...
